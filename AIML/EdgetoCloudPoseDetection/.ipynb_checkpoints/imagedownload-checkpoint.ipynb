# %%
from google_images_download import google_images_download   #importing the library
from chromedriver_py import binary_path
from selenium import webdriver
response = google_images_download.googleimagesdownload() 
arguments = {"keywords":"bridge yoga pose, childs yoga pose, downward dog yoga pose, mountain yoga pose, plank yoga pose, seated forward bend yoga pose, tree yoga pose, triangle yoga pose, warrior yoga pose","limit":1000,"print_urls":False, 'chromedriver': r"C:\Users\steph\Desktop\Berkeley\MachineLearn\projects\chromedriver_win32\chromedriver", "format": "jpg"}   #creating list of arguments
paths = response.download(arguments)    #passing the arguments to the function
#print(paths)   #printing absolute paths of the downloaded images

# %%
response = google_images_download.googleimagesdownload()

# %%
arguments = {"keywords":"bridge yoga pose, childs yoga pose, downward dog yoga pose, mountain yoga pose, plank yoga pose, seated forward bend yoga pose, tree yoga pose, triangle yoga pose, warrior yoga pose","limit":1000,"print_urls":False, 'chromedriver': r"C:\Users\steph\Desktop\Berkeley\MachineLearn\projects\chromedriver_win32\chromedriver", "format": "jpg"}   #creating list of arguments
paths = response.download(arguments)    #passing the arguments to the function
#print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = bridge yoga pose
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9965013830fa> in <module>
#       1 arguments = {"keywords":"bridge yoga pose, childs yoga pose, downward dog yoga pose, mountain yoga pose, plank yoga pose, seated forward bend yoga pose, tree yoga pose, triangle yoga pose, warrior yoga pose","limit":1000,"print_urls":False, 'chromedriver': r"C:\Users\steph\Desktop\Berkeley\MachineLearn\projects\chromedriver_win32\chromedriver", "format": "jpg"}   #creating list of arguments
# ----> 2 paths = response.download(arguments)    #passing the arguments to the function
#       3 #print(paths)   #printing absolute paths of the downloaded images
#
# ...

# %%
arguments = {"keywords":"downward dog","limit":1000,"print_urls":False, 'chromedriver': r"C:\Users\steph\Desktop\Berkeley\MachineLearn\projects\chromedriver_win32\chromedriver"}   #creating list of arguments
paths = response.download(arguments)    #passing the arguments to the function
# Out:
# Item no.: 1 --> Item name = downward dog
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.2hp_290_1721_bjk.jpg
# Completed Image ====> 2.DownwardDog.jpg
# Completed Image ====> 3.story-image-5333.jpg
# Completed Image ====> 4.article-migration-image-1920x1080_DownwardFacingDogPose.jpg
# Completed Image ====> 5.downward_dog.png
# Completed Image ====> 6.downward-dog-3-15-rina.jpg
# Completed Image ====> 7.Down-Dog-1024x744.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 8.yoga-DOWNWARDDOG-2-850x1152.jpg
# Completed Image ====> 9.DownDog_9654.jpg
# Completed Image ====> 10.Downward-Facing-Dog.JPG
# Completed Image ====> 11.downdog-1.jpg
# Completed Image ====> 12.DownwardDog_annotated-cbf66b0bfdae43aebaa717604cf5f8a4.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 13.yoga-tips-for-men-down-dog.jpg
# ...
